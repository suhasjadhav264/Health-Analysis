# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

df = pd.read_csv('medical_examination.csv')
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
df['height'] = df['height']/100
df['BMI'] = df['weight']/df['height']**2
ok = [] 
for w in df['BMI']:
    if w>25:
         ok.append(1)
    else:
        
        ok.append(0)
df['Overweight'] = ok
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2    1.68    62.0    110     80            1     1
# 1          1  20228       1    1.56    85.0    140     90            3     1
# 2          2  18857       1    1.65    64.0    130     70            3     1
# 3          3  17623       2    1.69    82.0    150    100            1     1
# 4          4  17474       1    1.56    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2    1.68    76.0    120     80            1     1
# 69996  99995  22601       1    1.58   126.0    140     90            2     2
# 69997  99996  19066       2    1.83   105.0    180     90            3     1
# 69998  99998  22431       1    1.63    72.0    135     80            1     2
# 69999  99999  20540       1    1.70    72.0    120     80            2     1
#
# ...

# %%
df[['cholesterol', 'gluc']]
# Out:
#        cholesterol  gluc
# 0                1     1
# 1                3     1
# 2                3     1
# 3                1     1
# 4                1     1
# ...            ...   ...
# 69995            1     1
# 69996            2     2
# 69997            3     1
# 69998            1     2
# 69999            2     1
#
# [70000 rows x 2 columns]

# %%
df[['cholesterol', 'gluc']] = np.where(df[['cholesterol', 'gluc']]==1, 0, df[['cholesterol', 'gluc']])
df[['cholesterol', 'gluc']] = np.where(df[['cholesterol', 'gluc']]>1, 1, df[['cholesterol', 'gluc']])
df[['cholesterol', 'gluc']]
# Out:
#        cholesterol  gluc
# 0                0     0
# 1                1     0
# 2                1     0
# 3                0     0
# 4                0     0
# ...            ...   ...
# 69995            0     0
# 69996            1     1
# 69997            1     0
# 69998            0     1
# 69999            1     0
#
# [70000 rows x 2 columns]

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2    1.68    62.0    110     80            0     0
# 1          1  20228       1    1.56    85.0    140     90            1     0
# 2          2  18857       1    1.65    64.0    130     70            1     0
# 3          3  17623       2    1.69    82.0    150    100            0     0
# 4          4  17474       1    1.56    56.0    100     60            0     0
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2    1.68    76.0    120     80            0     0
# 69996  99995  22601       1    1.58   126.0    140     90            1     1
# 69997  99996  19066       2    1.83   105.0    180     90            1     0
# 69998  99998  22431       1    1.63    72.0    135     80            0     1
# 69999  99999  20540       1    1.70    72.0    120     80            1     0
#
# ...

# %%
df2 = df.melt(id_vars= ['cardio'], value_vars=['active', 'alco', 'cholesterol', 'gluc', 'Overweight', 'smoke'])
df2
# Out:
#         cardio variable  value
# 0            0   active      1
# 1            1   active      1
# 2            1   active      0
# 3            1   active      1
# 4            0   active      0
# ...        ...      ...    ...
# 419995       0    smoke      1
# 419996       1    smoke      0
# 419997       1    smoke      0
# 419998       1    smoke      0
# 419999       0    smoke      0
#
# [420000 rows x 3 columns]

# %%
"df2['value_counts'] = df2['value'].value_counts()\na = df2['value_counts']\ndf2.dropna()"
sns.catplot(data = df2, x= 'variable', kind='count', hue='value', col='cardio')

# %%
df.drop('BMI', axis=1, inplace=True)

df = df[df['ap_lo'] <= df['ap_hi']]
df = df[df['height'] >= df['height'].quantile(0.025)]
df = df[df['height'] <= df['height'].quantile(0.975)]
df = df[df['weight'] >= df['weight'].quantile(0.025)]
df = df[df['weight'] <= df['weight'].quantile(0.975)]

df_corr = df.corr()

df_corr
# Out:
#                    id       age    gender    height    weight     ap_hi  \
# id           1.000000  0.002623  0.003799  0.000221  0.000144  0.003489
# age          0.002623  1.000000 -0.018274 -0.077426  0.069705  0.018482
# gender       0.003799 -0.018274  1.000000  0.504722  0.130116  0.004941
# height       0.000221 -0.077426  0.504722  1.000000  0.248868  0.004300
# weight       0.000144  0.069705  0.130116  0.248868  1.000000  0.026527
# ap_hi        0.003489  0.018482  0.004941  0.004300  0.026527  1.000000
# ap_lo        0.000429  0.152787  0.059500  0.015356  0.223786  0.072260
# cholesterol  0.003867  0.129582 -0.037669 -0.064477  0.132686  0.022606
# gluc         0.002477  0.087280 -0.021178 -0.031410  0.104475  0.011004
# smoke       -0.002403 -0.044208  0.337682  0.187389  0.055805 -0.001978
# alco        -0.001039 -0.026956  0.169178  0.089257  0.058286  0.000607
# active       0.005890 -0.011471  0.007702 -0.005042 -0.012112 -0.000162
# ...

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2    1.68    62.0    110     80            0     0
# 1          1  20228       1    1.56    85.0    140     90            1     0
# 2          2  18857       1    1.65    64.0    130     70            1     0
# 3          3  17623       2    1.69    82.0    150    100            0     0
# 4          4  17474       1    1.56    56.0    100     60            0     0
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69993  99991  19699       1    1.72    70.0    130     90            0     0
# 69994  99992  21074       1    1.65    80.0    150     80            0     0
# 69995  99993  19240       2    1.68    76.0    120     80            0     0
# 69998  99998  22431       1    1.63    72.0    135     80            0     1
# 69999  99999  20540       1    1.70    72.0    120     80            1     0
#
# ...

# %%
df['age'] = df['age']/365
df
# Out:
#           id        age  gender  height  weight  ap_hi  ap_lo  cholesterol  \
# 0          0  50.391781       2    1.68    62.0    110     80            0
# 1          1  55.419178       1    1.56    85.0    140     90            1
# 2          2  51.663014       1    1.65    64.0    130     70            1
# 3          3  48.282192       2    1.69    82.0    150    100            0
# 4          4  47.873973       1    1.56    56.0    100     60            0
# ...      ...        ...     ...     ...     ...    ...    ...          ...
# 69993  99991  53.969863       1    1.72    70.0    130     90            0
# 69994  99992  57.736986       1    1.65    80.0    150     80            0
# 69995  99993  52.712329       2    1.68    76.0    120     80            0
# 69998  99998  61.454795       1    1.63    72.0    135     80            0
# 69999  99999  56.273973       1    1.70    72.0    120     80            1
#
#        gluc  smoke  alco  active  cardio  Overweight
# ...

# %%
plt.style.use('dark_background')
plt.style.use('dark_background')
g = sns.catplot(x="weight", y="age", kind='bar', data=df)
g.figure.set_size_inches(90,20)
plt.xticks(rotation='vertical', size=20)
plt.yticks(size=20)
g.fig.suptitle("Categorial plot for age and weight", size=50)
g.set_axis_labels("Weight", 'Age', size=50)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-a9894205388d> in <module>
#       2 plt.style.use('dark_background')
#       3 g = sns.catplot(x="weight", y="age", kind='bar', data=df)
# ----> 4 g.figure.set_size_inches(90,20)
#       5 plt.xticks(rotation='vertical', size=20)
#       6 plt.yticks(size=20)
#
# AttributeError: 'FacetGrid' object has no attribute 'figure'

# %%
g = sns.catplot(x="weight", y="ap_hi", kind='bar', data=df)
g.figure.set_size_inches(90,20)
plt.xticks(rotation='vertical', size=20)
plt.yticks(size=20)
g.fig.suptitle("Categorial plot for Age and Systolic blood pressure", size=50)
g.set_axis_labels("Weight", 'Age', size=50)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-e8e6538aceb7> in <module>
#       1 g = sns.catplot(x="weight", y="ap_hi", kind='bar', data=df)
# ----> 2 g.figure.set_size_inches(90,20)
#       3 plt.xticks(rotation='vertical', size=20)
#       4 plt.yticks(size=20)
#       5 g.fig.suptitle("Categorial plot for Age and Systolic blood pressure", size=50)
#
# AttributeError: 'FacetGrid' object has no attribute 'figure'

# %%
g = sns.catplot(x="weight", y="ap_lo", kind='bar', data=df)
g.figure.set_size_inches(90,20)
plt.xticks(rotation='vertical', size=20)
plt.yticks(size=20)
g.fig.suptitle("Categorial plot for Age and Diastolic blood pressure", size=50)
g.set_axis_labels("Weight", 'Age', size=50)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-7a14c32a9c16> in <module>
#       1 g = sns.catplot(x="weight", y="ap_lo", kind='bar', data=df)
# ----> 2 g.figure.set_size_inches(90,20)
#       3 plt.xticks(rotation='vertical', size=20)
#       4 plt.yticks(size=20)
#       5 g.fig.suptitle("Categorial plot for Age and Diastolic blood pressure", size=50)
#
# AttributeError: 'FacetGrid' object has no attribute 'figure'

# %%
mask = np.zeros_like(df_corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style('dark'):
    f, ax = plt.subplots(figsize=(16, 12))
    g = sns.heatmap(df_corr, mask=mask, annot = True, annot_kws={'size': 8}, vmax= .24, fmt='0.1f')
